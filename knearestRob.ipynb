# %%
import pandas as pd

movies = pd.read_csv("https://raw.githubusercontent.com/4GeeksAcademy/k-nearest-neighbors-project-tutorial/main/tmdb_5000_movies.csv")
credits = pd.read_csv("https://raw.githubusercontent.com/4GeeksAcademy/k-nearest-neighbors-project-tutorial/main/tmdb_5000_credits.csv")

movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
import sqlite3

conn = sqlite3.connect("../data/movies_database.db")

movies.to_sql("movies_table", conn, if_exists = "replace", index = False)
credits.to_sql("credits_table", conn, if_exists = "replace", index = False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[3], line 3
#       1 import sqlite3
# ----> 3 conn = sqlite3.connect("../data/movies_database.db")
#       5 movies.to_sql("movies_table", conn, if_exists = "replace", index = False)
#       6 credits.to_sql("credits_table", conn, if_exists = "replace", index = False)
#
# OperationalError: unable to open database file

# %%
import psycopg2
conn=psycopg2.connect(
    dbname="postgres",
    user="postgres",
    password="ManzanaOrganico1",
    host="localhost",
    port="5432"

)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[2], line 2
#       1 import psycopg2
# ----> 2 conn=psycopg2.connect(
#       3     dbname="postgres",
#       4     user="postgres",
#       5     password="ManzanaOrganico1",
#       6     host="localhost",
#       7     port="5432"
#       8
#       9 )
#
# File ~/.python/current/lib/python3.12/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# OperationalError: could not connect to server: Connection refused
# 	Is the server running on host "localhost" (::1) and accepting
# ...

# %%
conn = psycopg2.connect(
    dbname="postgres",
    user="postgres",
    password="ManzanaOrganico1",
    host="localhost",
    port="5432"
)

# %%
import psycopg2

# Connect to PostgreSQL
conn = psycopg2.connect(
    dbname="postgres",
    user="postgres",
    password="ManzanaOrganico1",
    host="localhost",
    port="5432"
)

cur = conn.cursor()

# Create table with JSONB columns for cast and crew
cur.execute("""
    CREATE TABLE IF NOT EXISTS tmdb_credits (
        movie_id INT PRIMARY KEY,
        title VARCHAR(255),
        "cast" JSONB,
        "crew" JSONB
    )
""")

conn.commit()
cur.close()
conn.close()

# %%
import pandas as pd
import psycopg2
from sqlalchemy import create_engine

# Load the CSV file
df = pd.read_csv("tmdb_500_credits.csv")

# Convert string JSON to actual JSON format
df["cast"] = df["cast"].apply(lambda x: x.replace("'", '"'))  # Ensure valid JSON
df["crew"] = df["crew"].apply(lambda x: x.replace("'", '"'))

# Connect to PostgreSQL using SQLAlchemy
engine = create_engine("postgresql://postgres:ManzanaOrganico1@localhost:5432/postgres")

# Upload to PostgreSQL
df.to_sql("tmdb_credits", engine, if_exists="replace", index=False)

print("CSV uploaded successfully!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 6
#       3 from sqlalchemy import create_engine
#       5 # Load the CSV file
# ----> 6 df = pd.read_csv("tmdb_500_credits.csv")
#       8 # Convert string JSON to actual JSON format
#       9 df["cast"] = df["cast"].apply(lambda x: x.replace("'", '"'))  # Ensure valid JSON
#
# ...

# %%
import pandas as pd

df = pd.read_csv("tmdb_5000_credits.csv")  # Use the correct file name
print(df.head())  # Check if the file loads correctly
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
import pandas as pd
import psycopg2
from sqlalchemy import create_engine
import json

# Load CSV
df = pd.read_csv("tmdb_5000_credits.csv")

# Convert `cast` and `crew` to JSON format
df["cast"] = df["cast"].apply(json.loads)  # Convert string to JSON
df["crew"] = df["crew"].apply(json.loads)

# Rename columns to avoid SQL reserved words
df.rename(columns={"cast": "cast_data", "crew": "crew_data"}, inplace=True)

# Connect to PostgreSQL using SQLAlchemy
engine = create_engine("postgresql://postgres:ManzanaOrganico1@localhost:5432/postgres")

# Upload data to PostgreSQL
df.to_sql("tmdb_credits", engine, if_exists="replace", index=False)

print("CSV uploaded successfully!")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File ~/.python/current/lib/python3.12/site-packages/sqlalchemy/engine/base.py:2115, in Connection._exec_insertmany_context(self, dialect, context)
#    2114     else:
# -> 2115         dialect.do_execute(
#    2116             cursor,
#    2117             sub_stmt,
#    2118             sub_params,
#    2119             context,
#    2120         )
#    2122 except BaseException as e:
#
# File ~/.python/current/lib/python3.12/site-packages/sqlalchemy/engine/default.py:942, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     941 def do_execute(self, cursor, statement, parameters, context=None):
# --> 942     cursor.execute(statement, parameters)
#
# ProgrammingError: can't adapt type 'dict'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
import pandas as pd
import psycopg2
from sqlalchemy import create_engine
import json

# Load CSV
df = pd.read_csv("tmdb_5000_credits.csv")

# Convert `cast` and `crew` columns from stringified JSON to valid JSON
df["cast"] = df["cast"].apply(json.loads)  # Convert string to JSON
df["crew"] = df["crew"].apply(json.loads)

# Rename columns to avoid SQL reserved words
df.rename(columns={"cast": "cast_data", "crew": "crew_data"}, inplace=True)

# Convert JSON objects to strings for PostgreSQL storage
df["cast_data"] = df["cast_data"].apply(json.dumps)
df["crew_data"] = df["crew_data"].apply(json.dumps)

# Connect to PostgreSQL using SQLAlchemy
engine = create_engine("postgresql://postgres:ManzanaOrganico1@localhost:5432/postgres")

# Upload data to PostgreSQL
df.to_sql("tmdb_credits", engine, if_exists="replace", index=False)

print("✅ CSV uploaded successfully!")
# Out:
# ✅ CSV uploaded successfully!

# %%
import pandas as pd
from sqlalchemy import create_engine

# Load the CSV file
movies_df = pd.read_csv("tmdb_5000_movies.csv")

# Show the first few rows
print(movies_df.head())
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

# Database connection setup
DATABASE_URL = "postgresql://postgres:ManzanaOrganico1@localhost:5432/postgres"
engine = create_engine(DATABASE_URL)

# Load the two tables into Pandas DataFrames
query_movies = "SELECT * FROM tmdb_movies"
query_credits = "SELECT * FROM tmdb_credits"

movies_df = pd.read_sql(query_movies, engine)
credits_df = pd.read_sql(query_credits, engine)

# Rename columns for a proper merge
movies_df.rename(columns={'id': 'movie_id'}, inplace=True)

# Merge the data on movie_id
merged_df = movies_df.merge(credits_df, on="movie_id", how="inner")

# Display the first few rows of the merged dataset
import ace_tools as tools
tools.display_dataframe_to_user(name="Merged TMDB Data", dataframe=merged_df)
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# File ~/.python/current/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1964, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1963     if not evt_handled:
# -> 1964         self.dialect.do_execute(
#    1965             cursor, str_statement, effective_parameters, context
#    1966         )
#    1968 if self._has_events or self.engine._has_events:
#
# File ~/.python/current/lib/python3.12/site-packages/sqlalchemy/engine/default.py:942, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     941 def do_execute(self, cursor, statement, parameters, context=None):
# --> 942     cursor.execute(statement, parameters)
#
# UndefinedTable: relation "tmdb_movies" does not exist
# LINE 1: SELECT * FROM tmdb_movies
#                       ^
#
#
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

# Database connection
DATABASE_URL = "postgresql://postgres:ManzanaOrganico1@localhost:5432/postgres"
engine = create_engine(DATABASE_URL)

# Load CSV
df_movies = pd.read_csv("tmdb_5000_movies.csv")

# Upload to PostgreSQL
df_movies.to_sql("tmdb_movies", engine, if_exists="replace", index=False)

print("Movies table uploaded successfully!")
# Out:
# Movies table uploaded successfully!

# %%
import pandas as pd
from sqlalchemy import create_engine

# Database connection
DATABASE_URL = "postgresql://postgres:ManzanaOrganico1@localhost:5432/postgres"
engine = create_engine(DATABASE_URL)

# SQL Query to join both tables on 'movie_id'
query = """
    SELECT 
        m.movie_id, 
        m.title, 
        m.budget, 
        m.revenue, 
        m.popularity, 
        m.vote_average, 
        c.cast, 
        c.crew
    FROM tmdb_movies m
    JOIN tmdb_credits c
    ON m.movie_id = c.movie_id
"""

# Load joined data into a Pandas DataFrame
df_joined = pd.read_sql(query, engine)

# Display the joined table
import ace_tools as tools
tools.display_dataframe_to_user(name="Joined Movies & Credits Data", dataframe=df_joined)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# File ~/.python/current/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1964, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1963     if not evt_handled:
# -> 1964         self.dialect.do_execute(
#    1965             cursor, str_statement, effective_parameters, context
#    1966         )
#    1968 if self._has_events or self.engine._has_events:
#
# File ~/.python/current/lib/python3.12/site-packages/sqlalchemy/engine/default.py:942, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     941 def do_execute(self, cursor, statement, parameters, context=None):
# --> 942     cursor.execute(statement, parameters)
#
# UndefinedColumn: column m.movie_id does not exist
# LINE 13:     ON m.movie_id = c.movie_id
#                 ^
# ...

# %%
import sqlite3

conn = sqlite3.connect("../data/movies_database.db")

movies.to_sql("movies_table", conn, if_exists = "replace", index = False)
credits.to_sql("credits_table", conn, if_exists = "replace", index = False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[16], line 3
#       1 import sqlite3
# ----> 3 conn = sqlite3.connect("../data/movies_database.db")
#       5 movies.to_sql("movies_table", conn, if_exists = "replace", index = False)
#       6 credits.to_sql("credits_table", conn, if_exists = "replace", index = False)
#
# OperationalError: unable to open database file

# %%
import sqlite3
import pandas as pd

# Define file paths
movies_file = "tmdb_5000_movies.csv"
credits_file = "tmdb_5000_credits.csv"

# Load CSV files into Pandas DataFrames
movies = pd.read_csv(movies_file)
credits = pd.read_csv(credits_file)

# Connect to SQLite database (creates the file if it doesn't exist)
conn = sqlite3.connect("movies_database.db")  # Saves database in the current directory

# Store DataFrames in the SQLite database
movies.to_sql("movies_table", conn, if_exists="replace", index=False)
credits.to_sql("credits_table", conn, if_exists="replace", index=False)

# Verify by printing first 5 rows from each table
print("Movies Table:")
print(pd.read_sql("SELECT * FROM movies_table LIMIT 5", conn))

print("\nCredits Table:")
print(pd.read_sql("SELECT * FROM credits_table LIMIT 5", conn))

# Close the database connection
conn.close()
# Out:
# Movies Table:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
import os

db_path = "../data/movies_database.db"

# Ensure the directory exists
os.makedirs(os.path.dirname(db_path), exist_ok=True)

# Now, connect to the database
conn = sqlite3.connect(db_path)

# %%
import sqlite3

conn = sqlite3.connect("../data/movies_database.db")

movies.to_sql("movies_table", conn, if_exists = "replace", index = False)
credits.to_sql("credits_table", conn, if_exists = "replace", index = False)
# Out:
# 4803

# %%
# Merge tables for creating a new DataFrame

query = """
    SELECT *
    FROM movies_table
    INNER JOIN credits_table
    ON movies_table.title = credits_table.title;
"""

total_data = pd.read_sql_query(query, conn)
conn.close()

total_data = total_data.loc[:, ~total_data.columns.duplicated()]
total_data.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
# Data transform as expected
import json

def load_json_safe(json_str, default_value = None):
    try:
        return json.loads(json_str)
    except (TypeError, json.JSONDecodeError):
        return default_value
    
total_data["genres"] = total_data["genres"].apply(lambda x: [item["name"] for item in json.loads(x)] if pd.notna(x) else None)
total_data["keywords"] = total_data["keywords"].apply(lambda x: [item["name"] for item in json.loads(x)] if pd.notna(x) else None)

total_data["cast"] = total_data["cast"].apply(lambda x: [item["name"] for item in json.loads(x)][:3] if pd.notna(x) else None)

total_data["crew"] = total_data["crew"].apply(lambda x: " ".join([crew_member['name'] for crew_member in load_json_safe(x) if crew_member['job'] == 'Director']))

total_data["overview"] = total_data["overview"].apply(lambda x: [x])

total_data.head()
# Out:
#       budget                                         genres  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]
# 1  300000000                   [Adventure, Fantasy, Action]
# 2  245000000                     [Action, Adventure, Crime]
# 3  250000000               [Action, Crime, Drama, Thriller]
# 4  260000000           [Action, Adventure, Science Fiction]
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [culture clash, future, space war, space colon...                en
# 1  [ocean, drug abuse, exotic island, east india ...                en
# ...

# %%
total_data["overview"] = total_data["overview"].apply(lambda x: [str(x)])
total_data["genres"] = total_data["genres"].apply(lambda x: [str(genre) for genre in x])
total_data["keywords"] = total_data["keywords"].apply(lambda x: [str(keyword) for keyword in x])
total_data["cast"] = total_data["cast"].apply(lambda x: [str(actor) for actor in x])
total_data["crew"] = total_data["crew"].apply(lambda x: [str(crew_member) for crew_member in x])

total_data["tags"] = total_data["overview"] + total_data["genres"] + total_data["keywords"] + total_data["cast"] + total_data["crew"]
total_data["tags"] = total_data["tags"].apply(lambda x: ",".join(x).replace(",", " "))

total_data.drop(columns = ["genres", "keywords", "cast", "crew", "overview"], inplace = True)

total_data.iloc[0].tags
# Out:
# "['In the 22nd century  a paraplegic Marine is dispatched to the moon Pandora on a unique mission  but becomes torn between following orders and protecting an alien civilization.'] Action Adventure Fantasy Science Fiction culture clash future space war space colony society space travel futuristic romance space alien tribe alien planet cgi marine soldier battle love affair anti war power relations mind and soul 3d Sam Worthington Zoe Saldana Sigourney Weaver J a m e s   C a m e r o n"

# %%
import os
import sqlite3
import pandas as pd

# Ensure the directory exists
csv_path = "../data/processed/clean_data.csv"
os.makedirs(os.path.dirname(csv_path), exist_ok=True)

# Save the CSV file
total_data.to_csv(csv_path, index=False)
print("✅ CSV file saved successfully!")

# Ensure database directory exists
db_path = "../data/movies_database.db"
os.makedirs(os.path.dirname(db_path), exist_ok=True)

# Connect to SQLite database
conn = sqlite3.connect(db_path)

# Save to SQLite
movies.to_sql("clean_movies_data", conn, if_exists="replace", index=False)
print("✅ Data saved to SQLite successfully!")

# Close connection
conn.close()
# Out:
# ✅ CSV file saved successfully!
# ✅ Data saved to SQLite successfully!

# %%
total_data.to_csv("../data/processed/clean_data.csv", index = False)

conn = sqlite3.connect("../data/movies_database.db")

movies.to_sql("clean_movies_data", conn, if_exists = "replace", index = False)
# Out:
# 4803

# %%
# KNN modeling
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors

vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(total_data["tags"])

model = NearestNeighbors(n_neighbors = 6, algorithm = "brute", metric = "cosine")
model.fit(tfidf_matrix)

def get_movie_recommendations(movie_title):
    movie_index = total_data[total_data["title"] == movie_title].index[0]
    distances, indices = model.kneighbors(tfidf_matrix[movie_index])
    similar_movies = [(total_data["title"][i], distances[0][j]) for j, i in enumerate(indices[0])]
    return similar_movies[1:]

input_movie = "How to Train Your Dragon"
recommendations = get_movie_recommendations(input_movie)
print("Film recommendations '{}'".format(input_movie))
for movie, distance in recommendations:
    print("- Film: {}".format(movie))
# Out:
# Film recommendations 'How to Train Your Dragon'
# - Film: How to Train Your Dragon 2
# - Film: Dragon Nest: Warriors' Dawn
# - Film: Pete's Dragon
# - Film: George and the Dragon
# - Film: Eragon

# %%
from pickle import dump

dump(model, open("../models/knn_neighbors-6_algorithm-brute_metric-cosine.sav", "wb"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[28], line 3
#       1 from pickle import dump
# ----> 3 dump(model, open("../models/knn_neighbors-6_algorithm-brute_metric-cosine.sav", "wb"))
#
# File ~/.local/lib/python3.12/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../models/knn_neighbors-6_algorithm-brute_metric-cosine.sav'

# %%
import os
from pickle import dump

# Define the model save path
model_path = "../models/knn_neighbors-6_algorithm-brute_metric-cosine.sav"

# Ensure the directory exists
os.makedirs(os.path.dirname(model_path), exist_ok=True)

# Save the model
with open(model_path, "wb") as f:
    dump(model, f)

print("✅ Model saved successfully at:", model_path)
# Out:
# ✅ Model saved successfully at: ../models/knn_neighbors-6_algorithm-brute_metric-cosine.sav

# %%
import os
from pickle import dump

# Save model in the current directory
model_path = "knn_neighbors-6_algorithm-brute_metric-cosine.sav"

with open(model_path, "wb") as f:
    dump(model, f)

print("✅ Model saved successfully:", os.path.abspath(model_path))
# Out:
# ✅ Model saved successfully: /workspaces/k-nearest-neighbors-project-tutorial/knn_neighbors-6_algorithm-brute_metric-cosine.sav
